# %% [markdown]
# ### 作業1：
#
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# > __[Credit Card Fraud Detection](https://www.kaggle.com/mlg-ulb/creditcardfraud)__
# > 人潮進的來，feedbacks出的去，該資料獲得Datasets中最多的Upvotes，所以我認為對於新手而言該資料被使用的次數和廣大的討論應該蠻具參考價值。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# > 該資料由ULB (Université Libre de Bruxelles) 的Machine Learning Group (http://mlg.ulb.ac.be) 在Data mining和詐欺偵測上的研究中所收集而成，資料收集自2013年九月歐洲信用卡持卡者的交易行為。
#
# 3. 蒐集而來的資料型態為何
# > 資料的檔案型態為table型的csv檔，欄位包含交易的時間(從第一筆transaction經過的秒數)、交易數量、交易是否為詐欺行為(1 for True, 0 for False)，以及半隨著28個為保護使用者個資而經過PCA降維的feature value。
#
# 4. 這組資料想解決的問題如何評估
# > 為了防止持卡人因詐欺行為產生的不正常交易而損失金錢，該資料希望可以讓信用卡公司從中辨識出可能的詐欺行為。由於該資料包含的284,807筆交易中只有492筆為詐欺行為，相當於只有0.172%的程度，所以屬於高度正負分布不均的資料。

# %% [markdown]
# ### 作業2：
#
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# > 先拋開費率這種變動大又容易受法規影響的問題，在計程車運輸服務業要提昇業績其實就是「降低空車率」，也就是最大化同時間在道路上營運車輛的載客率，避免車輛空轉浪費油耗及人力。有效的作法包含判斷平假日、尖離峰的時間來決定是否出車，以及民眾搭車的偏好時間、地點，甚至是熟客記錄等。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# > 資料可以由地方政府的年度問卷調查及產業分析的報表而來，或是各家計程車業者所累積的營運及派遣資料，又或者是叫車APP的user records or feedbacks。近年來有許多政府及業者開放資料協作的平台逐漸開放，或許以上提及的資料都慢慢能從該平台上取得，否則只能透過一般研究用問卷調查方式來從大眾或業者中收集資料。
#
# 3. 蒐集而來的資料型態為何
# > 不同資料源的資料想必是沒有統一的格式，因此必須透過人力或程式輔助重新清洗為統一的結構及格式，設計好欄位的schema，後續才能加以轉換或分析。可能的欄位包含駕駛編號、資料回傳時間、車輛座標等。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# > 要驗證提昇業績的成果，可能需要司機配合，在乘客尖峰時段，到分析出的熱點地區試行繞車載客，一段時間後再來與之前的財務獲利做比較，即可驗證及討論這樣的分析行為是否是能改善業績，或者造成哪些後續的影響。

# %% [markdown]
# ### 作業3：
#
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 197.048
# The Mean absolute error is 10.824
